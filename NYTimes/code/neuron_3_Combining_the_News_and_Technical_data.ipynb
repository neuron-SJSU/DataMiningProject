# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install tables
# Out:
# Requirement already satisfied: tables in /usr/local/lib/python3.6/dist-packages (3.4.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tables) (1.11.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.6.8)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from tables) (1.14.6)

# %%
import pandas as pd
import numpy as np
import json

# %%
#Path here

base_path = '/content/drive/My Drive/stocks_project/'
sp500_path = '/content/drive/My Drive/stocks_project/data/sp/^GSPC.csv'
created_data_path = base_path + 'data/created/data500.h5'
technical500_path = created_data_path + 'technical500.h5'
news_path = '/content/drive/My Drive/stocks_project/data/news/'

# %% [markdown]
# # Import Module

# %% [markdown]
# # Import technical Data

# %%
df = pd.read_hdf(technical500_path, "data")
#df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
#df.dropna(axis=0, inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-04  358.760010  358.760010  352.890015  355.670013  355.670013
# 1990-01-05  355.670013  355.670013  351.350006  352.200012  352.200012
# 1990-01-08  352.200012  354.239990  350.540009  353.790009  353.790009
# 1990-01-09  353.829987  354.170013  349.609985  349.619995  349.619995
# 1990-01-10  349.619995  349.619995  344.320007  347.309998  347.309998
#
#                Volume     lrets      MACD  stochastics       ATR
# Date
# 1990-01-04  177000000 -0.008650  0.000000          NaN  5.869995
# 1990-01-05  158530000 -0.009804 -0.036878          NaN  4.320007
# 1990-01-08  140110000  0.004504 -0.005628          NaN  3.699981
# 1990-01-09  155210000 -0.011857 -0.100883          NaN  4.560028
# 1990-01-10  175990000 -0.006629 -0.198862          NaN  5.299988

# %% [markdown]
# # Import News data and convert it from Json to pandas dataframe

# %%
def open_json(year, month):
    "Save as pandas dataframe"
    file_str = news_path + str(year) + '-' + '{:02}'.format(month) + '.json'
    with open(file_str) as data_file:    
        NYTimes_data = json.load(data_file)
    
    date_list = []
    df = pd.DataFrame()  
    df['News'] = None
    

    for i in range(len(NYTimes_data["response"]["docs"][:])):
        if NYTimes_data["response"]["docs"][i]["pub_date"][:10] not in df.index:
            df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]] = NYTimes_data["response"]["docs"][:][i]['headline']['main']
        else:
            df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]] = df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]].values + NYTimes_data["response"]["docs"][:][i]['headline']['main']
    
    df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
    df.sort_index(inplace=True)
    
    return df

# %% [markdown]
# # Merge technical data with News

# %%
def merge_news_price(df):
    all_news = pd.DataFrame()
    for i in range(1990, 2019):
        for j in range(1, 13):
            try:
                temp = open_json(i, j)
                all_news = all_news.append(temp)
                print("Completed {}-{}".format(i, j))
            except:
                pass
            
    all_news = pd.concat([df, all_news], axis=1)
    
    return all_news

# %%
data = merge_news_price(df)
# Out:
# Completed 1990-1
# Completed 1990-2
# Completed 1990-3
# Completed 1990-4
# Completed 1990-5
# Completed 1990-6
# Completed 1990-7
# Completed 1990-8
# Completed 1990-9
# Completed 1990-10
# Completed 1990-11
# Completed 1990-12
# Completed 1991-1
# Completed 1991-2
# Completed 1991-3
# Completed 1991-4
# Completed 1991-5
# Completed 1991-6
# Completed 1991-7
# Completed 1991-8
# Completed 1991-9
# Completed 1991-10
# Completed 1991-11
# Completed 1991-12
# Completed 1992-1
# Completed 1992-2
# Completed 1992-3
# 2018-10-25           NaN       NaN        NaN          NaN        NaN
# 2018-10-26           NaN       NaN        NaN          NaN        NaN
# 2018-10-27           NaN       NaN        NaN          NaN        NaN
# 2018-10-28           NaN       NaN        NaN          NaN        NaN
# 2018-10-29           NaN       NaN        NaN          NaN        NaN
# 2018-10-30           NaN       NaN        NaN          NaN        NaN
# 2018-10-31           NaN       NaN        NaN          NaN        NaN
# 2018-11-01           NaN       NaN        NaN          NaN        NaN
# 2018-11-02           NaN       NaN        NaN          NaN        NaN
# 2018-11-03           NaN       NaN        NaN          NaN        NaN
# 2018-11-04           NaN       NaN        NaN          NaN        NaN
# 2018-11-05           NaN       NaN        NaN          NaN        NaN
# 2018-11-06           NaN       NaN        NaN          NaN        NaN
#
#                                                          News
# 2018-10-08  In Boston, a Renewed Appreciation for the Babe...
# 2018-10-09  Hurricane Michael, Hope Hicks, Google Plus: Yo...
# 2018-10-10  Learning With: ‘Banksy Painting Self-Destructs...
# 2018-10-11  Corrections: October 11, 2018On Politics: Form...
# 2018-10-12  On Politics: Trump’s Fed Tirade Could Have Las...
# 2018-10-13  Game HuntingWhat Civil Rights History Can Teac...
# 2018-10-14  Their Land Defiled, Forest People Swap Flower ...
# 2018-10-15  What to Cook Right NowSears, N.F.L., Meghan Ma...
# 2018-10-16  Elizabeth Warren Has a Native American Ancesto...
# 2018-10-17  Why Does Japan Make It So Hard for Working Wom...
# 2018-10-18  Women Get Feet in the Door of the Car Design B...
# 2018-10-19  Letters to the EditorLearning With: ‘Elizabeth...
# 2018-10-20  Remains of 63 Fetuses and Infants Found at Sec...
# 2018-10-21  Kathryn Paul, Aaron BergerTish Hurley, James R...
# 2018-10-22  Khashoggi, Russia, Italy: Your Monday Briefing...
# 2018-10-23  Do You Wish You Had a Different Morning Routin...
# 2018-10-24  What Is Turkey’s Game?When Trump Phones Friend...
# 2018-10-25  Twitter Posts Another Profit as User Numbers D...
# 2018-10-26  Pipe Bombs, Plastics, Jamal Khashoggi: Your Fr...
# 2018-10-27  Hotel Review: In Newport Beach, Calif., Buckin...
# 2018-10-28  Sarah Cramer, Amy LeongThis Week’s Wedding Ann...
# 2018-10-29  Red Bulls Clinch M.L.S. Regular-Season TitleWh...
# 2018-10-30  Austerity Is Over, Britain Says, Despite Brexi...
# 2018-10-31  Samsung Reaps Record Profit, but Tougher Times...
# 2018-11-01  California Today: Google Employees Around the ...
# 2018-11-02  Michael Cunningham Sings Leonard CohenThe Perv...
# 2018-11-03  30 of Our Best Thanksgiving Side DishesKnicks ...
# 2018-11-04  Caroline McWilliams Alsup, Justin BrownAmanda ...
# 2018-11-05  The Hall of Fame for Great Americans: As Forgo...
# 2018-11-06  Word + Quiz: stymieThe Beginning of the End fo...

# %% [markdown]
# # Export new data as a csv file

# %%
data.to_hdf(created_data_path, 'data')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['News']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
